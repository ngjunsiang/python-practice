# %% [markdown]
# # URL redirect removal
#
# When using a non-Chrome browser, Google search results redirect you through `google.com` before sending you to the URL that you requested.

# %% [markdown]
# ![google-redirect.png](attachment:google-redirect.png)

# %% [markdown]
# In the above image, the first search result has the following URL:
#
#     https://moz.com/learn/seo/redirection
#
# Google rewrites the link to:
#
#     https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&cad=rja&uact=8&ved=2ahUKEwjAhNDPz7zqAhVt_XMBHepeBf8QFjAAegQIBRAB&url=https%3A%2F%2Fmoz.com%2Flearn%2Fseo%2Fredirection&usg=AOvVaw0OxLud1UuZx_hO1HV9QrJ2
#
# Write a program that will undo the redirection and convert the redirect link back to the original URL.
#
# ### Example output:
#
#     >>> redirect_url = 'https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&cad=rja&uact=8&ved=2ahUKEwjAhNDPz7zqAhVt_XMBHepeBf8QFjAAegQIBRAB&url=https%3A%2F%2Fmoz.com%2Flearn%2Fseo%2Fredirection&usg=AOvVaw0OxLud1UuZx_hO1HV9QrJ2'
#     >>> undirect(redirect_url)
#     'https://moz.com/learn/seo/redirection'
#
# **\* Tip: Attempt the [Percent Encoding practice](percent-encoding.ipynb) first to learn about how the URL is converted.**

# %%
# Type your code here
